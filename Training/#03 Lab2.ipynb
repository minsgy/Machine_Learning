# %%
import tensorflow as tf

# 1. Build Graph using TF operations
# X and Y data, H(x) = Wx + b
# x_train = [1,2,3]
# y_train = [1,2,3]

# Shape 여부, random_normal([1]) 랜덤한 값 한개.
w = tf.Variable(tf.random_normal([1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")
x = tf.placeholder(tf.float32, shape=[None])
y = tf.placeholder(tf.float32, shape=[None])


#Our hypothesis (Wx+b)
hypothesis = w * x + b

# Cost(W, b)

#cost/Loss Function
cost = tf.reduce_mean(tf.square(hypothesis - y))
# reduce_mean : 갖고 있는 값을 평균 내주는 것.

# t = [1., 2., 3., 4.]
# tf.reduce_meat(t) ==> 2.5

#Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

#Launch the graph in a session
sess = tf.Session()
# Initailize 전역변수를 그래프안에 넣기.
sess.run(tf.global_variables_initializer())

#Fit the Line
for step in range(2001):
    cost_val, w_val, b_val, _ = sess.run([cost, w, b, train],
        #Train이라는 값은 학습을 위한.
        # x=1일때 y=2.1, ...
        feed_dict={x: [1,2,3,4,5], y: [2.1, 3.1, 4.1, 5.1, 6.1]})
    if step % 20 == 0:
        print(step, cost_val, w_val, b_val)
# Out:
# 0 75.53732 [-0.5962562] [-0.35542628]
# 20 0.14327465 [1.2352078] [0.21822102]
# 40 0.12377985 [1.2276039] [0.27812997]
# 60 0.10809778 [1.2127333] [0.3319647]
# 80 0.09440262 [1.1988014] [0.38226396]
# 100 0.08244256 [1.1857817] [0.42926905]
# 120 0.0719977 [1.1736147] [0.4731957]
# 140 0.06287612 [1.1622446] [0.5142457]
# 160 0.054910213 [1.151619] [0.5526071]
# 180 0.04795348 [1.1416894] [0.5884563]
# 200 0.04187814 [1.1324099] [0.6219577]
# 220 0.036572523 [1.1237384] [0.653265]
# 240 0.031939 [1.1156346] [0.6825221]
# 260 0.02789253 [1.1080616] [0.70986325]
# 280 0.024358753 [1.1009845] [0.7354137]
# 300 0.0212727 [1.094371] [0.75929075]
# 320 0.018577568 [1.0881904] [0.7816042]
# 340 0.016223963 [1.0824149] [0.80245614]
# 360 0.014168466 [1.0770173] [0.8219426]
# 380 0.012373464 [1.0719736] [0.8401528]
# 400 0.010805813 [1.0672598] [0.8571704]
# 420 0.009436816 [1.062855] [0.8730734]
# 440 0.008241245 [1.0587386] [0.88793504]
# 460 0.0071971444 [1.0548918] [0.9018233]
# 480 0.006285312 [1.0512967] [0.914802]
# 500 0.005488994 [1.0479374] [0.92693096]
# 520 0.0047935876 [1.0447979] [0.9382653]
# 540 0.004186269 [1.041864] [0.94885755]
# 560 0.0036559023 [1.0391223] [0.95875597]
# 580 0.0031927105 [1.0365602] [0.96800625]
# 600 0.002788232 [1.0341659] [0.9766504]
# 620 0.0024349934 [1.0319282] [0.98472875]
# 640 0.0021264893 [1.0298373] [0.9922779]
# 660 0.0018570821 [1.0278833] [0.9993327]
# 680 0.0016218072 [1.0260571] [1.0059254]
# 700 0.0014163278 [1.0243506] [1.0120864]
# 720 0.001236899 [1.0227559] [1.0178438]
# 740 0.0010801975 [1.0212657] [1.0232244]
# 760 0.0009433386 [1.0198729] [1.0282526]
# 780 0.00082382176 [1.0185714] [1.0329515]
# 800 0.0007194491 [1.0173551] [1.0373424]
# 820 0.0006283025 [1.0162185] [1.0414459]
# 840 0.00054870115 [1.0151564] [1.0452805]
# 860 0.0004791862 [1.0141639] [1.0488639]
# 880 0.00041848086 [1.0132363] [1.0522128]
# 900 0.0003654587 [1.0123694] [1.0553426]
# 920 0.00031915703 [1.0115594] [1.0582674]
# 940 0.00027871883 [1.0108023] [1.0610007]
# 960 0.00024340814 [1.0100948] [1.0635546]
# 980 0.00021257112 [1.0094336] [1.0659415]
# 1000 0.00018564177 [1.0088158] [1.068172]
# 1020 0.00016211586 [1.0082383] [1.070257]
# 1040 0.00014157653 [1.0076988] [1.0722048]
# 1060 0.00012364118 [1.0071946] [1.074025]
# 1080 0.00010797862 [1.0067234] [1.0757262]
# 1100 9.429846e-05 [1.0062832] [1.0773158]
# 1120 8.2352766e-05 [1.0058717] [1.0788013]
# 1140 7.191828e-05 [1.0054872] [1.0801893]
# 1160 6.280713e-05 [1.0051279] [1.0814867]
# 1180 5.4850687e-05 [1.004792] [1.0826993]
# 1200 4.7899626e-05 [1.0044782] [1.0838324]
# 1220 4.1833577e-05 [1.004185] [1.084891]
# 1240 3.653398e-05 [1.0039109] [1.0858805]
# 1260 3.190492e-05 [1.0036547] [1.0868052]
# 1280 2.7863038e-05 [1.0034155] [1.0876693]
# 1300 2.433151e-05 [1.0031917] [1.0884769]
# 1320 2.1248732e-05 [1.0029826] [1.0892315]
# 1340 1.8560628e-05 [1.0027875] [1.089936]
# 1360 1.6208765e-05 [1.002605] [1.0905952]
# 1380 1.4154078e-05 [1.0024344] [1.0912112]
# 1400 1.2361459e-05 [1.0022749] [1.0917869]
# 1420 1.0794827e-05 [1.0021259] [1.0923246]
# 1440 9.4272855e-06 [1.0019866] [1.0928273]
# 1460 8.233411e-06 [1.0018566] [1.093297]
# 1480 7.1899826e-06 [1.001735] [1.093736]
# 1500 6.279291e-06 [1.0016214] [1.0941464]
# 1520 5.483516e-06 [1.0015153] [1.0945296]
# 1540 4.7895196e-06 [1.001416] [1.0948877]
# 1560 4.181996e-06 [1.0013232] [1.0952226]
# 1580 3.6524784e-06 [1.0012367] [1.0955354]
# 1600 3.1896393e-06 [1.0011556] [1.0958279]
# 1620 2.7854503e-06 [1.0010799] [1.0961012]
# 1640 2.4326214e-06 [1.0010092] [1.0963565]
# 1660 2.1242424e-06 [1.0009431] [1.0965953]
# 1680 1.8548895e-06 [1.0008813] [1.0968183]
# 1700 1.6202517e-06 [1.0008236] [1.0970266]
# 1720 1.4151962e-06 [1.0007697] [1.0972211]
# 1740 1.235781e-06 [1.0007193] [1.097403]
# 1760 1.0793044e-06 [1.0006723] [1.097573]
# 1780 9.424648e-07 [1.0006282] [1.097732]
# 1800 8.23507e-07 [1.0005871] [1.0978802]
# 1820 7.190655e-07 [1.0005486] [1.098019]
# 1840 6.281796e-07 [1.0005128] [1.0981486]
# 1860 5.4845043e-07 [1.0004792] [1.0982697]
# 1880 4.7899454e-07 [1.0004479] [1.098383]
# 1900 4.1852468e-07 [1.0004187] [1.0984888]
# 1920 3.6550455e-07 [1.0003914] [1.0985876]
# 1940 3.1933774e-07 [1.0003656] [1.09868]
# 1960 2.7890633e-07 [1.0003417] [1.0987662]
# 1980 2.4364977e-07 [1.0003195] [1.0988469]
# 2000 2.1281883e-07 [1.0002984] [1.0989224]
